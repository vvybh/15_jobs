# %%
# 변수는 어떻게 만들까? 
a = 1
b = "python"
c = [1, 2, 3]

# 변수이름 = 변수에 저장할 값

# %%
# 변수 명명 규칙

# 1. 영문자, 숫자, 언더스코어(_) 만 가능 
# 2. 숫자로 변수명을 시작할 수 없음 -> l1(O), 1l(X)
# 3. 예약어는 사용할 수 없음 -> list, print, del 
# 4. 대소문자 구분한다. 

_private = "비공개"
userName = "ken"
user_name = "ken"
# user-name = "ken" (X)

UserName = "ken"

a = 12

# %%
# 변수를 만드는 여러가지 방법

a, b = "python", "life"

print(a)
print(b)

print(type(a))
# Out:
# python
# life
# <class 'str'>

# %%
[a, b] = ["python", "life"]

print(a)
print(type(a))
# Out:
# python
# <class 'str'>

# %%
a = b = "python"
print(a)
print(b)
# Out:
# python
# python

# %%
a = 3
b = 5

a, b = b, a

print(a)
print(b)
# Out:
# 5
# 3

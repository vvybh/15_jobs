# %%
# if 문은 왜 필요할까? 
# 돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다. 

money = True 
if money: print("택시를 타고 간다")
else: print("걸어간다")
# Out:
# 택시를 타고 간다

# %%
# if문의 기본 구조 
# if 조건문:
#     수행할문장1
#     수행할문장2
#     ...
# else:
#     수행할문장3
#     수행할문장4
#     ...

# %%
계란 = True 

if 계란 == True: 
    print("우유를 6개 사온다")
else:
    print("우유 1개 사온다 ")
# Out:
# 우유를 6개 사온다

# %%
money = True 
if money: 
    print("택시를")
    print("타고")
    print("간다")
# Out:
# 택시를
# 타고
# 간다

# %%
# 만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고, 
# 그렇지 않으면 걸어가라

money = 2000

if money >= 3000:
    print("택시를 타고 간다")
else: 
    print("걸어가라")
# Out:
# 걸어가라

# %%
# 만약 3000원 이상 있거나 카드가 있다면 택시를 타고 가고, 
# 그렇지 않으면 걸어가라

money = 2000
card = True

if money >= 3000 or card: 
    print("택시를 타고 가라")
else: 
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
# 만약에 주머니에 돈이 있으면 택시를 타고 가고, 그렇지 않으면 걸아가라 

주머니 = ["돈", "카드"]
if "동전" in 주머니:
    print("택시를 타고 가라")
else: 
    print("걸어가라")
# Out:
# 걸어가라

# %%
# 주머니에 돈이 있으면 택시를 타고 가고 
# 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고 
# 돈도 없고 카드도 없으면 걸어가라
# Out:
# ''

# %%
주머니 = ["돈", "시계", "폰"]
card = True

if "돈" in 주머니: 
    print("택시를 타고 가라")
else: 
    if card: 
        print("택시를 타고 가라")
    else: 
        print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
# 다양한 조건을 판단하는 elif
# 주머니에 돈이 있으면 택시를 타고 가고 
# 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고 
# 돈도 없고 카드도 없으면 걸어가라

주머니 = ["시계", "폰"]
card = False

if "돈" in 주머니: 
    print("택시를 타고 가라")
elif card: 
    print("택시를 타고 가라")
else: 
    print("걸어가라")
# Out:
# 걸어가라

# %%
# match-case 문
# 학점이 A이면 "탁월한 성적입니다."
# B이면 우수한 성적입니다.
# C이면 보통입니다
# 그외는 노력이 필요합니다

grade = "B"
if grade == "A":
    print("탁월한 성적입니다")
elif grade == "B":
    print("우수한 성적입니다")
elif grade == "C":
    print("보통입니다")
else:
    print("노력이 필요합니다")
# Out:
# 우수한 성적입니다

# %%
grade = "B"
match grade: 
    case "A":
        print("탁월한 성적입니다")
    case "B": 
        print("우수한 성적입니다")
    case "C":
        print("보통입니다")
    case _:
        print("노력이 필요합니다")
# Out:
# 우수한 성적입니다

# %%
# 비교 연산의 연쇄 사용
x = 5 
1 < x < 10

x > 1 and x < 10
# Out:
# True

# %%
# input 사용하기 
a = input()

# %%
print(a)
# Out:
# hello

# %%
a = int(input("첫번재 숫자를 입력해주세요"))
b = int(input("두번째 숫자를 입력해주세요"))

print(a+b)
# Out:
# 110

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
# 사용자로 부터 숫자를 입력을 받습니다. 
# 0 이상 100 이하의 숫자만 받습니다. <- 프롬프트 
# 19 이상이면 성인입니다. 
# 그렇지 않으면 미성년입니다. 

age = int(input("0 이상 100 이하의 숫자만 입력하세요 :"))

if age >= 19: 
    status = "성인"
else: 
    status = "미성년"

print(status)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       1 # 사용자로 부터 숫자를 입력을 받습니다.
#       2 # 0 이상 100 이하의 숫자만 받습니다. <- 프롬프트
#       3 # 19 이상이면 성인입니다.
#       4 # 그렇지 않으면 미성년입니다.
# ----> 6 age = int(input("0 이상 100 이하의 숫자만 입력하세요 :"))
#       8 if age >= 19:
#       9     status = "성인"
#
# ValueError: invalid literal for int() with base 10: ''

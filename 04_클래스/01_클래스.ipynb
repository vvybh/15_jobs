# %%
result = 0 

def add(num): 
    global result 
    result = result + num
    return result 

print(add(3))
print(add(4))
print(add(5))

result2 = 0

def add2(num):
    global result2
    result2 = result2 + num
    return result2 

print(add2(7))
print(add2(8))
# Out:
# 3
# 7
# 12
# 7
# 15

# %%
class Calculator:
    def __init__(self): 
        self.result = 0 

    def add(self, num):
        self.result = self.result + num
        return self.result 
    

cal1 = Calculator()
print(type(cal1))
cal1.result

# print(cal1.add(3))
# print(cal1.add(4))

# cal2 = Calculator()

# print(cal2.add(5))
# print(cal2.add(6))
# Out:
# <class '__main__.Calculator'>
# 0

# %%
class Calculator:
    def __init__(self): 
        self.result = 0 

    def add(self, num):
        self.result = self.result + num
        return self.result 
    
    def sub(self, num): 
        self.result -= num 
        return self.result 
    
    def mul(self, num):
        self.result *= num
        return self.result 
    
    def div(self, num): 
        self.result /= num 
        return self.result 
    

    

cal3 = Calculator()
cal3.add(7)
cal3.sub(4)
cal3.mul(2)
cal3.div(3)
# Out:
# 2.0

# %%
# 객체에 연산할 숫자 지정하기 
class FourCal:
    def setdata(self, first, second): 
        self.first = first 
        self.second = second 
    
    def add(self):
        result = self.first + self.second
        return result 
    
    def sub(self): 
        result = self.first - self.second 
        return result 
    
    def mul(self): 
        result = self.first * self.second 
        return result 

    def div(self):
        result = self.first / self.second 
        return result 


cal4 = FourCal()
cal4.setdata(3, 4)
print(cal4.first)
print(cal4.second)

cal5 = FourCal()
cal5.setdata(10, 20)

print(cal5.add())
print(cal5.sub())
print(cal5.mul())
print(cal5.div())
# Out:
# 3
# 4
# 30
# -10
# 200
# 0.5

# %%
class FourCal:
    def __init__(self, first, second): 
        self.first = first 
        self.second = second

    # def setdata(self, first, second): 
    #     self.first = first 
    #     self.second = second 

    
    def add(self):
        result = self.first + self.second
        return result 
    
    def sub(self): 
        result = self.first - self.second 
        return result 
    
    def mul(self): 
        result = self.first * self.second 
        return result 

    def div(self):
        result = self.first / self.second 
        return result 
    

cal6 = FourCal(3, 4)
print(cal6.first)
print(cal6.second)
cal6.add()

cal6.add()
# Out:
# 3
# 4
# 7

# %%
# 클래스의 상속

class MoreFourCal(FourCal):
    pass 

m1 = MoreFourCal(10, 20)
m1.add()
# Out:
# 30

# %%
class MoreFourCal(FourCal):
    def pow(self): 
        result = self.first ** self.second
        return result

# %%
m2 = MoreFourCal(10, 4)

print(m2.pow())
m2.add()
# Out:
# 10000
# 14

# %%
# 매서드 오버라이딩 

m3 = FourCal(4, 0)
m3.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 # 매서드 오버라이딩
#       3 m3 = FourCal(4, 0)
# ----> 4 m3.div()
#
# Cell In[5], line 24, in FourCal.div(self)
#      23 def div(self):
# ---> 24     result = self.first / self.second
#      25     return result
#
# ZeroDivisionError: division by zero

# %%
class SafeFourCal(FourCal): 
    def div(self): 
        if self.second == 0: 
            return 0
        else:
            result = self.first / self.second 
            return result

# %%
m5 = SafeFourCal(10, 0)

m5.div()
# Out:
# 0
